# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# 設定 macOS 專用中文字體
rcParams['font.family'] = 'PingFang TC'
rcParams['axes.unicode_minus'] = False  # 正常顯示負號

# %%
plt.figure(figsize=(6, 4))
plt.title("台積電與0056報酬率分析")  # 中文測試
plt.xlabel("台積電報酬率")
plt.ylabel("0056報酬率")
plt.plot([0.01, 0.02, 0.03], [0.003, 0.006, 0.009])
plt.grid()
plt.show()
# Out:
# findfont: Font family 'PingFang TC' not found.
# findfont: Font family 'PingFang TC' not found.
# findfont: Font family 'PingFang TC' not found.
# findfont: Font family 'PingFang TC' not found.
# findfont: Font family 'PingFang TC' not found.
# findfont: Font family 'PingFang TC' not found.
# findfont: Font family 'PingFang TC' not found.
# findfont: Font family 'PingFang TC' not found.
# findfont: Font family 'PingFang TC' not found.
# /Users/adamliao/文件/PythonWeb/venv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22577 (\N{CJK UNIFIED IDEOGRAPH-5831}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/adamliao/文件/PythonWeb/venv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 37228 (\N{CJK UNIFIED IDEOGRAPH-916C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
